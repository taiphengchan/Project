# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 2)

# %% [markdown]
# ### Description of the problem

# %% [markdown]
# Bubble tea, which is a popular drink in Asia, attracts more and more customers in European market in recent years. Many Bubble tea brands come to open their stores in France, especially in Paris, which is one of the top touristic destination and receive the visitors around the world each year.
#
# One well-known bubble tea brand wants to enter this potential market in Paris and looks for a good location to set up their shop. The criteria for the decision are:
# 1. Not far from the center of Paris
# 2. Not far from famous attractions
# 3. Having less existing bubble tea shops
#
# We will analyze which neighborhood is the best place for him to open his store.
#
# The audience of this project could be the investor or bubble tea shops owner or anyone who wants to research about this market.

# %% [markdown]
# ### Description of the data

# %% [markdown]
# First of all, we will search for some popular attractions in Paris and list them down. Then, we will use Foursquare API to extract all the Bubble tea shops in Paris. After that, we will cluster those bubble tea shops according to their GPS coordinates (latitudes and longitudes) by making the attractions as their centroids. At the end, we could suggestion which cluster has the less existing shops and near which attraction.

# %% [markdown]
# ### Methodology

# %%
#!pip install geopandas
#!pip install geopy

# %%
import pandas as pd
from pandas.io.json import json_normalize

from  geopy.geocoders import Nominatim

import folium

import requests

from sklearn.cluster import KMeans
import numpy as np 

import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# We list some famous landmarks in Paris

# %%
List = {'Attractions':['Tour Eiffel','Louvre museum','Arc de Triomphe','Sacre-Coeur','Le Jardin du Luxembourg','Notre-Dame de Paris']}

# %%
df = pd.DataFrame.from_dict(List)
df
# Out:
#                Attractions
# 0              Tour Eiffel
# 1            Louvre museum
# 2          Arc de Triomphe
# 3              Sacre-Coeur
# 4  Le Jardin du Luxembourg
# 5      Notre-Dame de Paris

# %% [markdown]
# Using geocoder, we generate the coordonates (latitudes and longitudes) of those attractions.

# %%
lst_lat = []
lst_lon = []
for row in df['Attractions']:
    locator = Nominatim(user_agent="myGeocoder")
    location = locator.geocode(row)
    lst_lat.append(location.latitude)
    lst_lon.append(location.longitude)

# %%
df['Latitude']=lst_lat
df['Longitude']=lst_lon

# %%
df
# Out:
#                Attractions   Latitude  Longitude
# 0              Tour Eiffel  48.858260   2.294499
# 1            Louvre museum  48.861147   2.338028
# 2          Arc de Triomphe  48.873779   2.295037
# 3              Sacre-Coeur  48.886806   2.343015
# 4  Le Jardin du Luxembourg  48.846723   2.336413
# 5      Notre-Dame de Paris  48.852937   2.350050

# %% [markdown]
# The coordonates of the center of Paris is

# %%
paris_center=[48.864716,2.349014]

# %% [markdown]
# We illustrate those attractions in map

# %%
map_paris = folium.Map(location=paris_center, zoom_start=13)
for lat_att, lng_att, label_att in zip(df['Latitude'], df['Longitude'], df['Attractions']):
    folium.Marker([lat_att, lng_att], popup=label_att).add_to(map_paris)
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Then we will find the center point between those attractions in order to extract the bubble tea shops nearby.

# %%
import math

x = 0.0
y = 0.0
z = 0.0

for i, coord in df.iterrows():
    latitude = math.radians(coord.Latitude)
    longitude = math.radians(coord.Longitude)

    x += math.cos(latitude) * math.cos(longitude)
    y += math.cos(latitude) * math.sin(longitude)
    z += math.sin(latitude)

total = len(df)

x = x / total
y = y / total
z = z / total

central_longitude = math.atan2(y, x)
central_square_root = math.sqrt(x * x + y * y)
central_latitude = math.atan2(z, central_square_root)

mean_location = {
    'latitude': math.degrees(central_latitude),
    'longitude': math.degrees(central_longitude)
    }

mean_location
# Out:
# {'latitude': 48.863277588502456, 'longitude': 2.3261744551090393}

# %%
lat_mean_loc = mean_location.get('latitude')
lng_mean_loc = mean_location.get('longitude')

# %% [markdown]
# After getting the center point, we start to use Foursquare API to list down all the bubble shops in range.

# %%
client_id = 'P0W2UCI31FPMCPIKMJSM4QV3ZS3OEEBMOEUFY2J0U0F1ESYE' # your Foursquare ID
client_secret = 'HSWPYXPZRZMRD1UAKI30WMXHTBSNJHX055X3Y5ZAROPBQR3W' # your Foursquare Secret
version = '20200711' # Foursquare API version

# %%
categoryId = '52e81612bcbc57f1066b7a0c' # bubble tea shop
radius = 5000
LIMIT = 100

# %%
# create the API request URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(
    client_id, client_secret, lat_mean_loc, lng_mean_loc, version, categoryId, radius, LIMIT)
            
#make the GET request
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1307150af06e78b9cf5e08'},
#  'response': {'venues': [{'id': '5841c5b38ee56078594b3924',
#     'name': 'Momen’Tea',
#     'location': {'address': "5 avenue de l'Opéra",
#      'lat': 48.86494065438193,
#      'lng': 2.334791630066141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86494065438193,
#        'lng': 2.334791630066141}],
#      'distance': 657,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'neighborhood': 'Palais-Royal',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["5 avenue de l'Opéra", '75001 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5a8c1166e1f22874f4fc9714',
#     'name': 'Laïzé 來座 (Laïzé)',
#     'location': {'address': '19 rue de Montmorency',
#      'lat': 48.86307722773456,
#      'lng': 2.355072994853153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86307722773456,
#        'lng': 2.355072994853153}],
#      'distance': 2116,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'neighborhood': 'Rambuteau',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['19 rue de Montmorency', '75003 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b0add16419a9e002cafd160',
#     'name': 'The Alley',
#     'location': {'address': '55 rue des Petits Champs',
#      'lat': 48.867163069709555,
#      'lng': 2.3347824811935425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867163069709555,
#        'lng': 2.3347824811935425}],
#      'distance': 764,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['55 rue des Petits Champs',
#       '75001 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5ec408840ac2020008c89ab0',
#     'name': 'Meng Salon de Thé',
#     'location': {'address': '35 bis rue du Roi de Sicile',
#      'lat': 48.8566430396361,
#      'lng': 2.3564788548537763,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8566430396361,
#        'lng': 2.3564788548537763}],
#      'distance': 2339,
#      'postalCode': '75004',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['35 bis rue du Roi de Sicile',
#       '75004 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5bfaa273c03635002c8d12e2',
#     'name': 'Tree Tea',
#     'location': {'address': '8 rue Buffault',
#      'lat': 48.875071,
#      'lng': 2.341695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.875071,
#        'lng': 2.341695}],
#      'distance': 1736,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['8 rue Buffault', '75009 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5ddfd5ecb298290008f18bb3',
#     'name': 'The Alley',
#     'location': {'address': '13 Boulevard Haussmann',
#      'lat': 48.872562,
#      'lng': 2.3355033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.872562,
#        'lng': 2.3355033}],
#      'distance': 1238,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['13 Boulevard Haussmann', '75009 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5ca0e90e088158002c0b9e34',
#     'name': 'Thé Point',
#     'location': {'lat': 48.859543,
#      'lng': 2.377089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.859543,
#        'lng': 2.377089}],
#      'distance': 3751,
#      'postalCode': '75011',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75011 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5ad1ed5d3149b90df0a3ab0c',
#     'name': 'Chatime',
#     'location': {'address': '19 quai des Grands Augustins',
#      'lat': 48.85406,
#      'lng': 2.343399,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85406,
#        'lng': 2.343399}],
#      'distance': 1626,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['19 quai des Grands Augustins',
#       '75006 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5a60f10e0c9f317921ca8c84',
#     'name': 'Chatime',
#     'location': {'address': '89 rue Beaubourg',
#      'lat': 48.86421365202117,
#      'lng': 2.3549231886863704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86421365202117,
#        'lng': 2.3549231886863704}],
#      'distance': 2107,
#      'postalCode': '75004',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['89 rue Beaubourg', '75004 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5e0a0f5f26886900085fdfeb',
#     'name': 'CoCo Fresh Tea & Juice',
#     'location': {'address': '6 rue Dante',
#      'lat': 48.85127481320342,
#      'lng': 2.3464393615722656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85127481320342,
#        'lng': 2.3464393615722656}],
#      'distance': 1997,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['6 rue Dante', '75005 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '4e58fa4fd22dfba6f46cc50d',
#     'name': 'Boba Tea Shop',
#     'location': {'address': "103 avenue d'Ivry",
#      'lat': 48.82425429815104,
#      'lng': 2.3662589706348744,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.82425429815104,
#        'lng': 2.3662589706348744}],
#      'distance': 5243,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["103 avenue d'Ivry", '75013 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b97de5ac62b49002c701f82',
#     'name': 'Bubble My Tea',
#     'location': {'address': '5 rue de Mirbel',
#      'lat': 48.84064170960753,
#      'lng': 2.352148443460464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.84064170960753,
#        'lng': 2.352148443460464}],
#      'distance': 3157,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['5 rue de Mirbel', '75005 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b11446d588e36002c6b14c1',
#     'name': 'Bubble Shop',
#     'location': {'address': '34 avenue des Champs-Élysées',
#      'lat': 48.87022699110948,
#      'lng': 2.3082178831100464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87022699110948,
#        'lng': 2.3082178831100464}],
#      'distance': 1525,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['34 avenue des Champs-Élysées',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d4d8cfc79431800070eeefd',
#     'name': 'Totoro',
#     'location': {'address': '89 rue Monge',
#      'lat': 48.841735,
#      'lng': 2.352185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.841735,
#        'lng': 2.352185}],
#      'distance': 3062,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['89 rue Monge', '75005 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5378cf9c498eb51533fa33bc',
#     'name': 'Yi Yun',
#     'location': {'address': '13 rue Thérèse',
#      'lat': 48.866037,
#      'lng': 2.335741,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.866037,
#        'lng': 2.335741}],
#      'distance': 764,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['13 rue Thérèse', '75001 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d173c04e32452002306666c',
#     'name': 'Tao',
#     'location': {'address': '1 rue Brantôme',
#      'crossStreet': 'Rue Rambuteau',
#      'lat': 48.86153695266959,
#      'lng': 2.352537363767624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86153695266959,
#        'lng': 2.352537363767624}],
#      'distance': 1940,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['1 rue Brantôme (Rue Rambuteau)',
#       '75003 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b4358d53ba767002cea0b62',
#     'name': 'Chatime',
#     'location': {'address': '4 rue Mouffetard',
#      'lat': 48.844831,
#      'lng': 2.349086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.844831,
#        'lng': 2.349086}],
#      'distance': 2651,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['4 rue Mouffetard', '75005 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5cc3178f60d11b002cc7c945',
#     'name': 'Sin Heaven',
#     'location': {'lat': 48.861554,
#      'lng': 2.37062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.861554,
#        'lng': 2.37062}],
#      'distance': 3260,
#      'postalCode': '75011',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75011 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5cacd183112c6c002ce744af',
#     'name': 'YinYoo 饮悦工坊',
#     'location': {'address': '7 Rue des Prêcheurs',
#      'crossStreet': 'Rue Pierre Lescot',
#      'lat': 48.862005,
#      'lng': 2.348798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.862005,
#        'lng': 2.348798}],
#      'distance': 1662,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['7 Rue des Prêcheurs (Rue Pierre Lescot)',
#       '75001 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '592eae3131ac6c14dc9dc7a2',
#     'name': 'Chatime',
#     'location': {'address': '124 avenue de Choisy',
#      'lat': 48.8265745978865,
#      'lng': 2.3596576599855923,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8265745978865,
#        'lng': 2.3596576599855923}],
#      'distance': 4765,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['124 avenue de Choisy', '75013 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d04c62b59c423002c92b537',
#     'name': 'YITHÉ 以茶',
#     'location': {'address': '49 Boulevard de Sébastopol',
#      'lat': 48.861885,
#      'lng': 2.34991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.861885,
#        'lng': 2.34991}],
#      'distance': 1745,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['49 Boulevard de Sébastopol',
#       '75001 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b4cc9569e3b65002c507f8c',
#     'name': 'Chatime Voltaire',
#     'location': {'lat': 48.854196,
#      'lng': 2.385719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.854196,
#        'lng': 2.385719}],
#      'distance': 4476,
#      'postalCode': '75011',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75011 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d7548a452634b0008ba8710',
#     'name': 'Xing Fu Tang Bubble Tea',
#     'location': {'lat': 48.86521,
#      'lng': 2.357621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86521,
#        'lng': 2.357621}],
#      'distance': 2312,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75003 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d20d3b9a24dd70023bfff4e',
#     'name': 'Chatime',
#     'location': {'address': '99 Rue de Rivoli',
#      'lat': 48.861423,
#      'lng': 2.334191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.861423,
#        'lng': 2.334191}],
#      'distance': 622,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['99 Rue de Rivoli', '75001 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5ce15c5a916bc1002cfe7385',
#     'name': 'Bubble Vie',
#     'location': {'lat': 48.884746,
#      'lng': 2.340215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.884746,
#        'lng': 2.340215}],
#      'distance': 2601,
#      'postalCode': '75018',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75018 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b24014ac876c8002c0c5290',
#     'name': 'TeaYammi',
#     'location': {'address': '10 Rue Des Moulins',
#      'lat': 48.86676,
#      'lng': 2.335194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86676,
#        'lng': 2.335194}],
#      'distance': 765,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['10 Rue Des Moulins', '75001 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1dc931735',
#       'name': 'Tea Room',
#       'pluralName': 'Tea Rooms',
#       'shortName': 'Tea Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d2dbcabafbe290023a2482d',
#     'name': 'Pause Goût Thé',
#     'location': {'address': '54 Rue Richer',
#      'lat': 48.874078,
#      'lng': 2.343102,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.874078,
#        'lng': 2.343102}],
#      'distance': 1726,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['54 Rue Richer', '75009 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '56fd10d9498edb20df341710',
#     'name': 'cojean',
#     'location': {'lat': 48.866776,
#      'lng': 2.302553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.866776,
#        'lng': 2.302553}],
#      'distance': 1773,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '4dcd31811f6eb122705aa801',
#     'name': 'TeaWan',
#     'location': {'address': "128 avenue d'Ivry",
#      'lat': 48.82647371601319,
#      'lng': 2.359860593212244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.82647371601319,
#        'lng': 2.359860593212244}],
#      'distance': 4782,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["128 avenue d'Ivry", 'Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d0407db8c35dc002ca9795b',
#     'name': 'Bubble Wrap',
#     'location': {'lat': 48.831245,
#      'lng': 2.380666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.831245,
#        'lng': 2.380666}],
#      'distance': 5352,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75013 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5cb1fdedb3c961002c3976a1',
#     'name': 'NEKOTEA',
#     'location': {'address': '15 rue Gregoire de Tours',
#      'lat': 48.852999,
#      'lng': 2.337865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.852999,
#        'lng': 2.337865}],
#      'distance': 1429,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['15 rue Gregoire de Tours',
#       '75006 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5c7565729411f2002c8ca686',
#     'name': 'Mr. Ye',
#     'location': {'lat': 48.833694,
#      'lng': 2.354325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.833694,
#        'lng': 2.354325}],
#      'distance': 3885,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75013 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5d6e3ec101817000087d5444',
#     'name': 'Tea House',
#     'location': {'address': '7 Rue Montorgueil',
#      'lat': 48.863421,
#      'lng': 2.3463,
#      'labeledLatLngs': [{'label': 'display', 'lat': 48.863421, 'lng': 2.3463}],
#      'distance': 1473,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['7 Rue Montorgueil', '75001 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5cfd172a50e7c80023dbdb1b',
#     'name': "O'naicha 香閣",
#     'location': {'address': '31 rue de Ponthieu',
#      'lat': 48.87100026372004,
#      'lng': 2.3083412647247314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87100026372004,
#        'lng': 2.3083412647247314}],
#      'distance': 1563,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['31 rue de Ponthieu', '75008 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5e21b67f568f980008610d46',
#     'name': 'Ang',
#     'location': {'lat': 48.828225,
#      'lng': 2.380477,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.828225,
#        'lng': 2.380477}],
#      'distance': 5572,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['75013 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '54844e3f498e8f59ce25f290',
#     'name': 'Cha Bubble Tea',
#     'location': {'lat': 48.869032,
#      'lng': 2.356284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.869032,
#        'lng': 2.356284}],
#      'distance': 2296,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5cb307a81c675b002c070d0a',
#     'name': 'M63 Paris Salon De Thé',
#     'location': {'address': 'Boulevard de Rochechouart',
#      'lat': 48.881978,
#      'lng': 2.340832,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.881978,
#        'lng': 2.340832}],
#      'distance': 2342,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Boulevard de Rochechouart',
#       '75009 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5ab6820b037be12b647b70fc',
#     'name': 'Teawan',
#     'location': {'address': '30 Rue Mouffetard',
#      'lat': 48.843928,
#      'lng': 2.349368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.843928,
#        'lng': 2.349368}],
#      'distance': 2743,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['30 Rue Mouffetard', '75005 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5c2d36f50fe7a00039d6ddc2',
#     'name': 'Miruku Ti',
#     'location': {'address': '4 Rue des Gravilliers',
#      'lat': 48.863482,
#      'lng': 2.358031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.863482,
#        'lng': 2.358031}],
#      'distance': 2333,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['4 Rue des Gravilliers', '75003 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5b02a7ded8096e002c1baa40',
#     'name': 'Coco Lafayette',
#     'location': {'address': '9 Rue Joubert',
#      'lat': 48.874583,
#      'lng': 2.331605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.874583,
#        'lng': 2.331605}],
#      'distance': 1319,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['9 Rue Joubert', '75009 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5559d59c498e157730f3ec9d',
#     'name': 'Chatime',
#     'location': {'address': '33 rue de Richelieu',
#      'lat': 48.8653197674037,
#      'lng': 2.3366653131823787,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8653197674037,
#        'lng': 2.3366653131823787}],
#      'distance': 801,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['33 rue de Richelieu', '75001 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5001951de4b04575fdb89702',
#     'name': 'ZenZoo – Bar à Thé',
#     'location': {'address': '2 rue Chabanais',
#      'lat': 48.867020860798846,
#      'lng': 2.336737853474915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867020860798846,
#        'lng': 2.336737853474915}],
#      'distance': 878,
#      'postalCode': '75002',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['2 rue Chabanais', '75002 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '5305f35b11d2d1eb14a204fa',
#     'name': 'Le 37m²',
#     'location': {'address': '64 rue Sainte-Anne',
#      'lat': 48.868636125459105,
#      'lng': 2.3367217602208257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.868636125459105,
#        'lng': 2.3367217602208257}],
#      'distance': 975,
#      'postalCode': '75002',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['64 rue Sainte-Anne', '75002 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '59fdf0f4d1a4022b95e6cc5b',
#     'name': 'Bon goûthé',
#     'location': {'address': '60 Rue Des Entrepreneurs',
#      'lat': 48.845575,
#      'lng': 2.288094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.845575,
#        'lng': 2.288094}],
#      'distance': 3415,
#      'postalCode': '75015',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['60 Rue Des Entrepreneurs',
#       '75015 Paris',
#       'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '4b9e1e38f964a520abcb36e3',
#     'name': 'Zen Zoo',
#     'location': {'address': '41 rue Coquillière',
#      'lat': 48.86463032532642,
#      'lng': 2.340844715643271,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86463032532642,
#        'lng': 2.340844715643271}],
#      'distance': 1084,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['41 rue Coquillière', '75001 Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '586bcfa858c4d132e393243d',
#     'name': 'Tchat Huant',
#     'location': {'lat': 48.85234,
#      'lng': 2.333649,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85234,
#        'lng': 2.333649}],
#      'distance': 1334,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Paris', 'France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False},
#    {'id': '55e18491498ebe4561ef3d5d',
#     'name': 'Boba Tea Coffee',
#     'location': {'lat': 48.82618713378906,
#      'lng': 2.358802556991577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.82618713378906,
#        'lng': 2.358802556991577}],
#      'distance': 4770,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['France']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#       'name': 'Bubble Tea Shop',
#       'pluralName': 'Bubble Tea Shops',
#       'shortName': 'Bubble Tea',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1595082552',
#     'hasPerk': False}],
#   'confident': False}}

# %%
venues = results['response']['venues']
    
nearby_venues = json_normalize(venues) # flatten JSON

nearby_venues
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                           id                     name  \
# 0   5841c5b38ee56078594b3924                Momen’Tea
# 1   5a8c1166e1f22874f4fc9714         Laïzé 來座 (Laïzé)
# 2   5b0add16419a9e002cafd160                The Alley
# 3   5ec408840ac2020008c89ab0        Meng Salon de Thé
# 4   5bfaa273c03635002c8d12e2                 Tree Tea
# 5   5ddfd5ecb298290008f18bb3                The Alley
# 6   5ca0e90e088158002c0b9e34                Thé Point
# 7   5ad1ed5d3149b90df0a3ab0c                  Chatime
# 8   5a60f10e0c9f317921ca8c84                  Chatime
# 9   5e0a0f5f26886900085fdfeb   CoCo Fresh Tea & Juice
# 10  4e58fa4fd22dfba6f46cc50d            Boba Tea Shop
# 11  5b97de5ac62b49002c701f82            Bubble My Tea
# 12  5b11446d588e36002c6b14c1              Bubble Shop
# 13  5d4d8cfc79431800070eeefd                   Totoro
# 14  5378cf9c498eb51533fa33bc                   Yi Yun
# 15  5d173c04e32452002306666c                      Tao
# 16  5b4358d53ba767002cea0b62                  Chatime
# 17  5cc3178f60d11b002cc7c945               Sin Heaven
# 18  5cacd183112c6c002ce744af              YinYoo 饮悦工坊
# 19  592eae3131ac6c14dc9dc7a2                  Chatime
# 20  5d04c62b59c423002c92b537                 YITHÉ 以茶
# 21  5b4cc9569e3b65002c507f8c         Chatime Voltaire
# 22  5d7548a452634b0008ba8710  Xing Fu Tang Bubble Tea
# 23  5d20d3b9a24dd70023bfff4e                  Chatime
# 24  5ce15c5a916bc1002cfe7385               Bubble Vie
# 25  5b24014ac876c8002c0c5290                 TeaYammi
# 26  5d2dbcabafbe290023a2482d           Pause Goût Thé
# 27  56fd10d9498edb20df341710                   cojean
# 28  4dcd31811f6eb122705aa801                   TeaWan
# 29  5d0407db8c35dc002ca9795b              Bubble Wrap
# 30  5cb1fdedb3c961002c3976a1                  NEKOTEA
# 31  5c7565729411f2002c8ca686                   Mr. Ye
# 32  5d6e3ec101817000087d5444                Tea House
# 33  5cfd172a50e7c80023dbdb1b              O'naicha 香閣
# 34  5e21b67f568f980008610d46                      Ang
# 35  54844e3f498e8f59ce25f290           Cha Bubble Tea
# 36  5cb307a81c675b002c070d0a   M63 Paris Salon De Thé
# 37  5ab6820b037be12b647b70fc                   Teawan
# 38  5c2d36f50fe7a00039d6ddc2                Miruku Ti
# 39  5b02a7ded8096e002c1baa40           Coco Lafayette
# 40  5559d59c498e157730f3ec9d                  Chatime
# 41  5001951de4b04575fdb89702       ZenZoo – Bar à Thé
# 42  5305f35b11d2d1eb14a204fa                  Le 37m²
# 43  59fdf0f4d1a4022b95e6cc5b               Bon goûthé
# 44  4b9e1e38f964a520abcb36e3                  Zen Zoo
# 45  586bcfa858c4d132e393243d              Tchat Huant
# 46  55e18491498ebe4561ef3d5d          Boba Tea Coffee
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 1   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 2   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 3   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 4   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 5   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 6   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 7   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 8   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 9   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 10  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 11  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 12  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 13  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 14  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 15  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 16  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 17  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 18  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 19  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 20  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 21  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 22  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 23  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 24  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 25  [{'id': '4bf58dd8d48988d1dc931735', 'name': 'T...  v-1595082552    False
# 26  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 27  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 28  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 29  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 30  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 31  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 32  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 33  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 34  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 35  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 36  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 37  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 38  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595082552    False
# 39  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 40  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 41  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 42  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1595082552    False
# 43  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 44  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 45  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
# 46  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595082552    False
#
#                 location.address  location.lat  location.lng  \
# 0            5 avenue de l'Opéra     48.864941      2.334792
# 1          19 rue de Montmorency     48.863077      2.355073
# 2       55 rue des Petits Champs     48.867163      2.334782
# 3    35 bis rue du Roi de Sicile     48.856643      2.356479
# 4                 8 rue Buffault     48.875071      2.341695
# 5         13 Boulevard Haussmann     48.872562      2.335503
# 6                            NaN     48.859543      2.377089
# 7   19 quai des Grands Augustins     48.854060      2.343399
# 8               89 rue Beaubourg     48.864214      2.354923
# 9                    6 rue Dante     48.851275      2.346439
# 10             103 avenue d'Ivry     48.824254      2.366259
# 11               5 rue de Mirbel     48.840642      2.352148
# 12  34 avenue des Champs-Élysées     48.870227      2.308218
# 13                  89 rue Monge     48.841735      2.352185
# 14                13 rue Thérèse     48.866037      2.335741
# 15                1 rue Brantôme     48.861537      2.352537
# 16              4 rue Mouffetard     48.844831      2.349086
# 17                           NaN     48.861554      2.370620
# 18           7 Rue des Prêcheurs     48.862005      2.348798
# 19          124 avenue de Choisy     48.826575      2.359658
# 20    49 Boulevard de Sébastopol     48.861885      2.349910
# 21                           NaN     48.854196      2.385719
# 22                           NaN     48.865210      2.357621
# 23              99 Rue de Rivoli     48.861423      2.334191
# 24                           NaN     48.884746      2.340215
# 25            10 Rue Des Moulins     48.866760      2.335194
# 26                 54 Rue Richer     48.874078      2.343102
# 27                           NaN     48.866776      2.302553
# 28             128 avenue d'Ivry     48.826474      2.359861
# 29                           NaN     48.831245      2.380666
# 30      15 rue Gregoire de Tours     48.852999      2.337865
# 31                           NaN     48.833694      2.354325
# 32             7 Rue Montorgueil     48.863421      2.346300
# 33            31 rue de Ponthieu     48.871000      2.308341
# 34                           NaN     48.828225      2.380477
# 35                           NaN     48.869032      2.356284
# 36     Boulevard de Rochechouart     48.881978      2.340832
# 37             30 Rue Mouffetard     48.843928      2.349368
# 38         4 Rue des Gravilliers     48.863482      2.358031
# 39                 9 Rue Joubert     48.874583      2.331605
# 40           33 rue de Richelieu     48.865320      2.336665
# 41               2 rue Chabanais     48.867021      2.336738
# 42            64 rue Sainte-Anne     48.868636      2.336722
# 43      60 Rue Des Entrepreneurs     48.845575      2.288094
# 44            41 rue Coquillière     48.864630      2.340845
# 45                           NaN     48.852340      2.333649
# 46                           NaN     48.826187      2.358803
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 48.86494065438193...                657
# 1   [{'label': 'display', 'lat': 48.86307722773456...               2116
# 2   [{'label': 'display', 'lat': 48.86716306970955...                764
# 3   [{'label': 'display', 'lat': 48.8566430396361,...               2339
# 4   [{'label': 'display', 'lat': 48.875071, 'lng':...               1736
# 5   [{'label': 'display', 'lat': 48.872562, 'lng':...               1238
# 6   [{'label': 'display', 'lat': 48.859543, 'lng':...               3751
# 7   [{'label': 'display', 'lat': 48.85406, 'lng': ...               1626
# 8   [{'label': 'display', 'lat': 48.86421365202117...               2107
# 9   [{'label': 'display', 'lat': 48.85127481320342...               1997
# 10  [{'label': 'display', 'lat': 48.82425429815104...               5243
# 11  [{'label': 'display', 'lat': 48.84064170960753...               3157
# 12  [{'label': 'display', 'lat': 48.87022699110948...               1525
# 13  [{'label': 'display', 'lat': 48.841735, 'lng':...               3062
# 14  [{'label': 'display', 'lat': 48.866037, 'lng':...                764
# 15  [{'label': 'display', 'lat': 48.86153695266959...               1940
# 16  [{'label': 'display', 'lat': 48.844831, 'lng':...               2651
# 17  [{'label': 'display', 'lat': 48.861554, 'lng':...               3260
# 18  [{'label': 'display', 'lat': 48.862005, 'lng':...               1662
# 19  [{'label': 'display', 'lat': 48.8265745978865,...               4765
# 20  [{'label': 'display', 'lat': 48.861885, 'lng':...               1745
# 21  [{'label': 'display', 'lat': 48.854196, 'lng':...               4476
# 22  [{'label': 'display', 'lat': 48.86521, 'lng': ...               2312
# 23  [{'label': 'display', 'lat': 48.861423, 'lng':...                622
# 24  [{'label': 'display', 'lat': 48.884746, 'lng':...               2601
# 25  [{'label': 'display', 'lat': 48.86676, 'lng': ...                765
# 26  [{'label': 'display', 'lat': 48.874078, 'lng':...               1726
# 27  [{'label': 'display', 'lat': 48.866776, 'lng':...               1773
# 28  [{'label': 'display', 'lat': 48.82647371601319...               4782
# 29  [{'label': 'display', 'lat': 48.831245, 'lng':...               5352
# 30  [{'label': 'display', 'lat': 48.852999, 'lng':...               1429
# 31  [{'label': 'display', 'lat': 48.833694, 'lng':...               3885
# 32  [{'label': 'display', 'lat': 48.863421, 'lng':...               1473
# 33  [{'label': 'display', 'lat': 48.87100026372004...               1563
# 34  [{'label': 'display', 'lat': 48.828225, 'lng':...               5572
# 35  [{'label': 'display', 'lat': 48.869032, 'lng':...               2296
# 36  [{'label': 'display', 'lat': 48.881978, 'lng':...               2342
# 37  [{'label': 'display', 'lat': 48.843928, 'lng':...               2743
# 38  [{'label': 'display', 'lat': 48.863482, 'lng':...               2333
# 39  [{'label': 'display', 'lat': 48.874583, 'lng':...               1319
# 40  [{'label': 'display', 'lat': 48.8653197674037,...                801
# 41  [{'label': 'display', 'lat': 48.86702086079884...                878
# 42  [{'label': 'display', 'lat': 48.86863612545910...                975
# 43  [{'label': 'display', 'lat': 48.845575, 'lng':...               3415
# 44  [{'label': 'display', 'lat': 48.86463032532642...               1084
# 45  [{'label': 'display', 'lat': 48.85234, 'lng': ...               1334
# 46  [{'label': 'display', 'lat': 48.82618713378906...               4770
#
#    location.postalCode location.cc location.neighborhood location.city  \
# 0                75001          FR          Palais-Royal         Paris
# 1                75003          FR             Rambuteau         Paris
# 2                75001          FR                   NaN         Paris
# 3                75004          FR                   NaN         Paris
# 4                75009          FR                   NaN         Paris
# 5                75009          FR                   NaN         Paris
# 6                75011          FR                   NaN         Paris
# 7                75006          FR                   NaN         Paris
# 8                75004          FR                   NaN         Paris
# 9                75005          FR                   NaN         Paris
# 10               75013          FR                   NaN         Paris
# 11               75005          FR                   NaN         Paris
# 12               75008          FR                   NaN         Paris
# 13               75005          FR                   NaN         Paris
# 14               75001          FR                   NaN         Paris
# 15               75003          FR                   NaN         Paris
# 16               75005          FR                   NaN         Paris
# 17               75011          FR                   NaN         Paris
# 18               75001          FR                   NaN         Paris
# 19               75013          FR                   NaN         Paris
# 20               75001          FR                   NaN         Paris
# 21               75011          FR                   NaN         Paris
# 22               75003          FR                   NaN         Paris
# 23               75001          FR                   NaN         Paris
# 24               75018          FR                   NaN         Paris
# 25               75001          FR                   NaN         Paris
# 26               75009          FR                   NaN         Paris
# 27                 NaN          FR                   NaN           NaN
# 28                 NaN          FR                   NaN         Paris
# 29               75013          FR                   NaN         Paris
# 30               75006          FR                   NaN         Paris
# 31               75013          FR                   NaN         Paris
# 32               75001          FR                   NaN         Paris
# 33               75008          FR                   NaN         Paris
# 34               75013          FR                   NaN         Paris
# 35                 NaN          FR                   NaN           NaN
# 36               75009          FR                   NaN         Paris
# 37               75005          FR                   NaN         Paris
# 38               75003          FR                   NaN         Paris
# 39               75009          FR                   NaN         Paris
# 40               75001          FR                   NaN         Paris
# 41               75002          FR                   NaN         Paris
# 42               75002          FR                   NaN         Paris
# 43               75015          FR                   NaN         Paris
# 44               75001          FR                   NaN         Paris
# 45                 NaN          FR                   NaN         Paris
# 46                 NaN          FR                   NaN           NaN
#
#    location.state location.country  \
# 0   Île-de-France           France
# 1   Île-de-France           France
# 2   Île-de-France           France
# 3   Île-de-France           France
# 4   Île-de-France           France
# 5   Île-de-France           France
# 6   Île-de-France           France
# 7   Île-de-France           France
# 8   Île-de-France           France
# 9   Île-de-France           France
# 10  Île-de-France           France
# 11  Île-de-France           France
# 12  Île-de-France           France
# 13  Île-de-France           France
# 14  Île-de-France           France
# 15  Île-de-France           France
# 16  Île-de-France           France
# 17  Île-de-France           France
# 18  Île-de-France           France
# 19  Île-de-France           France
# 20  Île-de-France           France
# 21  Île-de-France           France
# 22  Île-de-France           France
# 23  Île-de-France           France
# 24  Île-de-France           France
# 25  Île-de-France           France
# 26  Île-de-France           France
# 27            NaN           France
# 28  Île-de-France           France
# 29  Île-de-France           France
# 30  Île-de-France           France
# 31  Île-de-France           France
# 32  Île-de-France           France
# 33  Île-de-France           France
# 34  Île-de-France           France
# 35            NaN           France
# 36  Île-de-France           France
# 37  Île-de-France           France
# 38  Île-de-France           France
# 39  Île-de-France           France
# 40  Île-de-France           France
# 41  Île-de-France           France
# 42  Île-de-France           France
# 43  Île-de-France           France
# 44  Île-de-France           France
# 45  Île-de-France           France
# 46            NaN           France
#
#                             location.formattedAddress location.crossStreet
# 0          [5 avenue de l'Opéra, 75001 Paris, France]                  NaN
# 1        [19 rue de Montmorency, 75003 Paris, France]                  NaN
# 2     [55 rue des Petits Champs, 75001 Paris, France]                  NaN
# 3   [35 bis rue du Roi de Sicile, 75004 Paris, Fra...                  NaN
# 4               [8 rue Buffault, 75009 Paris, France]                  NaN
# 5       [13 Boulevard Haussmann, 75009 Paris, France]                  NaN
# 6                               [75011 Paris, France]                  NaN
# 7   [19 quai des Grands Augustins, 75006 Paris, Fr...                  NaN
# 8             [89 rue Beaubourg, 75004 Paris, France]                  NaN
# 9                  [6 rue Dante, 75005 Paris, France]                  NaN
# 10           [103 avenue d'Ivry, 75013 Paris, France]                  NaN
# 11             [5 rue de Mirbel, 75005 Paris, France]                  NaN
# 12  [34 avenue des Champs-Élysées, 75008 Paris, Fr...                  NaN
# 13                [89 rue Monge, 75005 Paris, France]                  NaN
# 14              [13 rue Thérèse, 75001 Paris, France]                  NaN
# 15  [1 rue Brantôme (Rue Rambuteau), 75003 Paris, ...        Rue Rambuteau
# 16            [4 rue Mouffetard, 75005 Paris, France]                  NaN
# 17                              [75011 Paris, France]                  NaN
# 18  [7 Rue des Prêcheurs (Rue Pierre Lescot), 7500...    Rue Pierre Lescot
# 19        [124 avenue de Choisy, 75013 Paris, France]                  NaN
# 20  [49 Boulevard de Sébastopol, 75001 Paris, France]                  NaN
# 21                              [75011 Paris, France]                  NaN
# 22                              [75003 Paris, France]                  NaN
# 23            [99 Rue de Rivoli, 75001 Paris, France]                  NaN
# 24                              [75018 Paris, France]                  NaN
# 25          [10 Rue Des Moulins, 75001 Paris, France]                  NaN
# 26               [54 Rue Richer, 75009 Paris, France]                  NaN
# 27                                           [France]                  NaN
# 28                 [128 avenue d'Ivry, Paris, France]                  NaN
# 29                              [75013 Paris, France]                  NaN
# 30    [15 rue Gregoire de Tours, 75006 Paris, France]                  NaN
# 31                              [75013 Paris, France]                  NaN
# 32           [7 Rue Montorgueil, 75001 Paris, France]                  NaN
# 33          [31 rue de Ponthieu, 75008 Paris, France]                  NaN
# 34                              [75013 Paris, France]                  NaN
# 35                                           [France]                  NaN
# 36   [Boulevard de Rochechouart, 75009 Paris, France]                  NaN
# 37           [30 Rue Mouffetard, 75005 Paris, France]                  NaN
# 38       [4 Rue des Gravilliers, 75003 Paris, France]                  NaN
# 39               [9 Rue Joubert, 75009 Paris, France]                  NaN
# 40         [33 rue de Richelieu, 75001 Paris, France]                  NaN
# 41             [2 rue Chabanais, 75002 Paris, France]                  NaN
# 42          [64 rue Sainte-Anne, 75002 Paris, France]                  NaN
# 43    [60 Rue Des Entrepreneurs, 75015 Paris, France]                  NaN
# 44          [41 rue Coquillière, 75001 Paris, France]                  NaN
# 45                                    [Paris, France]                  NaN
# 46                                           [France]                  NaN

# %%
# filter columns
filtered_columns = ['name', 'location.lat', 'location.lng']
bubble_tea =nearby_venues[filtered_columns]
bubble_tea.shape
# Out:
# (47, 3)

# %%
bubble_tea.head()
# Out:
#                 name  location.lat  location.lng
# 0          Momen’Tea     48.864941      2.334792
# 1   Laïzé 來座 (Laïzé)     48.863077      2.355073
# 2          The Alley     48.867163      2.334782
# 3  Meng Salon de Thé     48.856643      2.356479
# 4           Tree Tea     48.875071      2.341695

# %% [markdown]
# We got in total 44 bubble tea shops. Let's illustrate in the map below.

# %%
map_paris = folium.Map(location=paris_center, zoom_start=13)
for lat_att, lng_att, label_att in zip(df['Latitude'], df['Longitude'], df['Attractions']):
    folium.Marker([lat_att, lng_att], popup=label_att).add_to(map_paris)
for lat_r, lon_r in zip (bubble_tea['location.lat'],bubble_tea['location.lng']):
    folium.Circle([lat_r,lon_r],radius=30, color = 'blue', fill=True).add_to(map_paris)

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The next step is to cluster those bubble tea shops according to their coordonates (latitudes and longitudes) by setting the attractions as their centroids.

# %%
X=bubble_tea.loc[:,['location.lat','location.lng']]
X.head()
# Out:
#    location.lat  location.lng
# 0     48.864941      2.334792
# 1     48.863077      2.355073
# 2     48.867163      2.334782
# 3     48.856643      2.356479
# 4     48.875071      2.341695

# %%
id_n=6
centroids = df[['Latitude','Longitude']].to_numpy()
kmeans = KMeans(n_clusters=id_n, init = centroids, max_iter =1 ).fit(X)
id_label=kmeans.labels_
id_label
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([1, 5, 1, 5, 3, 1, 5, 4, 5, 4, 5, 5, 2, 5, 1, 5, 5, 5, 1, 5, 1, 5,
#        5, 1, 3, 1, 3, 2, 5, 5, 4, 5, 1, 2, 5, 3, 3, 5, 5, 1, 1, 1, 1, 0,
#        1, 4, 5])

# %%
bubble_tea['Cluster']=id_label
bubble_tea.head()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                 name  location.lat  location.lng  Cluster
# 0          Momen’Tea     48.864941      2.334792        1
# 1   Laïzé 來座 (Laïzé)     48.863077      2.355073        5
# 2          The Alley     48.867163      2.334782        1
# 3  Meng Salon de Thé     48.856643      2.356479        5
# 4           Tree Tea     48.875071      2.341695        3

# %%
bubble_tea['Cluster'].value_counts()
# Out:
# 5    20
# 1    14
# 3     5
# 4     4
# 2     3
# 0     1
# Name: Cluster, dtype: int64

# %% [markdown]
# We got the result of our clusters. Let's view in map.

# %%
# create map
map_clusters = folium.Map(location=paris_center, zoom_start=13)

# set color scheme for the clusters
x = np.arange(id_n)
ys = [i + x + (i*x)**2 for i in range(id_n)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(bubble_tea['location.lat'], bubble_tea['location.lng'], bubble_tea['name'], bubble_tea['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color='white',
        fill_opacity=1.5).add_to(map_clusters)

for lat_att, lng_att, label_att in zip(df['Latitude'], df['Longitude'], df['Attractions']):
    folium.Marker([lat_att, lng_att], popup=label_att).add_to(map_clusters)       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Result

# %% [markdown]
# There are 20 bubble tea shops nearby Notre-Dame de Paris (Cluster 5, Orange color).
# <br>
# There are 14 bubble tea shops nearby Louvre Museum (Cluster 1, Purple color).
# <br>
# There are 5 bubble tea shops nearby from Sacre-Coeur (cluster 3, Light Blue color).
# <br>
# There are 4 bubble tea shops nearby Le Jardin du Luxembourg (cluster 4, Green color).
# <br>
# There are 3 bubble tea shops nearby Tour Eiffel and Arc de Triomphe (cluster 3, Blue color).
# <br>
# There are only 1 bubble tea shops far away from any attractions (cluster 2, Red color).

# %% [markdown]
# ### Discussion

# %% [markdown]
# According the result above, we could say that there are many bubble tea shops existing in the center of Paris, especially in the locations nearby Notre-Dame de Paris and Louvre Museum. However, there are few bubble tea shop around Arc de Triomphe and Tour Eiffel.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In conclusion, the investor should look for the location around __Arc de Triomphe or Tour Eiffel__. They are both the most famous monuments in Paris and the top destinations in Paris for tourists. In addition, there are still not many bubble tea shop opened yet, so this location should be considered.
